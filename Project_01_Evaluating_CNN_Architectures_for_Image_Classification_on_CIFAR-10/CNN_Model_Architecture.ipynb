# %% [markdown]
# # Deep Learning Project - 1 : CNN Model Architecture
# ---
# - ### Write a program to implement 3 different CNN architectures with a comparison table for the MNSIT or CIFAR10 dataset using the Tensorflow library.
#
# - ### Make sure your code is readable.
#
# - ### You should add comments wherever necessary for proper understanding. This will help others who read through your code understand what it does and how it works.
# ---

# %% [markdown]
# # Importing necessary libraries :

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# # Loading and preprocessing the **CIFAR10** dataset :
# ---
# - ###  Loading the **CIFAR10** dataset, splitting it into training and testing sets, and normalizing pixel values to a range of [0, 1].

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.cifar10.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0

# %% [markdown]
# # Defining the CNN architectures :
# ---
# ## **1. Simple CNN :**
# - ### Simple CNN with increased complexity and regularization.

# %%
def create_model1():
    model = models.Sequential()
    model.add(layers.Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(32, 32, 3)))
    model.add(layers.BatchNormalization()) # Batch Normalization added
    model.add(layers.Conv2D(32, (3, 3), activation='relu', padding='same'))
    model.add(layers.BatchNormalization())
    model.add(layers.MaxPooling2D((2, 2)))
    model.add(layers.Dropout(0.25))

    model.add(layers.Conv2D(64, (3, 3), activation='relu', padding='same'))
    model.add(layers.BatchNormalization())
    model.add(layers.Conv2D(64, (3, 3), activation='relu', padding='same'))
    model.add(layers.BatchNormalization())
    model.add(layers.MaxPooling2D((2, 2)))
    model.add(layers.Dropout(0.25))

    model.add(layers.Flatten())
    model.add(layers.Dense(512, activation='relu'))
    model.add(layers.Dropout(0.5))
    model.add(layers.Dense(10, activation='softmax'))  # Added softmax activation
    return model

# %% [markdown]
# ## **2. Deeper CNN with Dropout :**
# - ### **'create_model2'** is a deeper CNN with with Dropout and Batch Normalization.

# %%
def create_model2():
    model = models.Sequential()
    model.add(layers.Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(32, 32, 3)))
    model.add(layers.BatchNormalization())  # Added Batch Normalization
    model.add(layers.Conv2D(32, (3, 3), activation='relu', padding='same'))
    model.add(layers.BatchNormalization())  # Added Batch Normalization
    model.add(layers.MaxPooling2D((2, 2)))
    model.add(layers.Dropout(0.25))  # keeping Dropout

    model.add(layers.Conv2D(64, (3, 3), activation='relu', padding='same'))
    model.add(layers.BatchNormalization())  # Added Batch Normalization
    model.add(layers.Conv2D(64, (3, 3), activation='relu', padding='same'))
    model.add(layers.BatchNormalization())  # Added Batch Normalization
    model.add(layers.MaxPooling2D((2, 2)))
    model.add(layers.Dropout(0.25))  # Keeping Dropout

    model.add(layers.Flatten())
    model.add(layers.Dense(512, activation='relu'))
    model.add(layers.Dropout(0.5))  # Keeping Dropout
    model.add(layers.Dense(10))
    return model

# %% [markdown]
# ## **3. CNN with Data Augmentation :**
# - ### **'create_model3'** is CNN model with Data Augmentation and Batch Normalization.

# %%
def create_model3():
    data_augmentation = keras.Sequential(
        [
            layers.RandomFlip("horizontal", input_shape=(32, 32, 3)),
            layers.RandomRotation(0.1),
            layers.RandomZoom(0.1),
        ]
    )

    model = models.Sequential()
    model.add(data_augmentation)  # Keeping Data Augmentation
    model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)))
    model.add(layers.BatchNormalization())  # Added Batch Normalization
    model.add(layers.MaxPooling2D((2, 2)))
    model.add(layers.Conv2D(64, (3, 3), activation='relu'))
    model.add(layers.BatchNormalization())  # Added Batch Normalization
    model.add(layers.MaxPooling2D((2, 2)))
    model.add(layers.Conv2D(64, (3, 3), activation='relu'))
    model.add(layers.Flatten())
    model.add(layers.Dense(64, activation='relu'))
    model.add(layers.Dense(10))
    return model

# %% [markdown]
# # Creating and compiling the models :
# - ### Below code creates, compiles (configures for training), and stores 3 CNN models with specified optimizers, loss functions, and metrics.

# %%
model1 = create_model1()
model2 = create_model2()
model3 = create_model3()

models = [model1, model2, model3]
model_names = ['Simple CNN', 'Deeper CNN with Dropout', 'CNN with Data Augmentation']

for model in models:
    model.compile(optimizer='adam',
                  loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                  metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/preprocessing/tf_data_layer.py:19: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %% [markdown]
# # Training the models and storing the history :

# %%
histories = []
for model in models:
    history = model.fit(x_train, y_train, epochs=10, validation_data=(x_test, y_test))  # Adjust epochs as needed
    histories.append(history)
# Out:
# Epoch 1/10
# /usr/local/lib/python3.10/dist-packages/keras/src/backend/tensorflow/nn.py:609: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 8ms/step - accuracy: 0.3736 - loss: 1.9765 - val_accuracy: 0.5747 - val_loss: 1.1969
# Epoch 2/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.5748 - loss: 1.2151 - val_accuracy: 0.6409 - val_loss: 1.0348
# Epoch 3/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.6475 - loss: 1.0116 - val_accuracy: 0.6976 - val_loss: 0.8666
# Epoch 4/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.6912 - loss: 0.9013 - val_accuracy: 0.7250 - val_loss: 0.7936
# Epoch 5/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.7224 - loss: 0.8093 - val_accuracy: 0.7459 - val_loss: 0.7480
# Epoch 6/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.7457 - loss: 0.7426 - val_accuracy: 0.7602 - val_loss: 0.7061
# Epoch 7/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.7654 - loss: 0.6818 - val_accuracy: 0.7889 - val_loss: 0.6267
# Epoch 8/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.7853 - loss: 0.6146 - val_accuracy: 0.7776 - val_loss: 0.6611
# Epoch 9/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.8071 - loss: 0.5595 - val_accuracy: 0.7884 - val_loss: 0.6479
# Epoch 10/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.8138 - loss: 0.5300 - val_accuracy: 0.7773 - val_loss: 0.6576
# Epoch 1/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 21s 8ms/step - accuracy: 0.3634 - loss: 1.9882 - val_accuracy: 0.5659 - val_loss: 1.2218
# Epoch 2/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - accuracy: 0.5751 - loss: 1.2126 - val_accuracy: 0.6236 - val_loss: 1.0581
# Epoch 3/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.6480 - loss: 1.0079 - val_accuracy: 0.7025 - val_loss: 0.8769
# Epoch 4/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.6913 - loss: 0.8970 - val_accuracy: 0.7340 - val_loss: 0.7747
# Epoch 5/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.7269 - loss: 0.7991 - val_accuracy: 0.7421 - val_loss: 0.7236
# Epoch 6/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.7450 - loss: 0.7361 - val_accuracy: 0.7594 - val_loss: 0.6990
# Epoch 7/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.7684 - loss: 0.6671 - val_accuracy: 0.7844 - val_loss: 0.6393
# Epoch 8/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.7846 - loss: 0.6203 - val_accuracy: 0.7782 - val_loss: 0.6356
# Epoch 9/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.8057 - loss: 0.5586 - val_accuracy: 0.7983 - val_loss: 0.5960
# Epoch 10/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.8165 - loss: 0.5256 - val_accuracy: 0.7871 - val_loss: 0.6236
# Epoch 1/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - accuracy: 0.4002 - loss: 1.6672 - val_accuracy: 0.4775 - val_loss: 1.4550
# Epoch 2/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 8ms/step - accuracy: 0.5356 - loss: 1.3036 - val_accuracy: 0.5812 - val_loss: 1.1715
# Epoch 3/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 8ms/step - accuracy: 0.5927 - loss: 1.1522 - val_accuracy: 0.5681 - val_loss: 1.2225
# Epoch 4/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 22s 9ms/step - accuracy: 0.6157 - loss: 1.0951 - val_accuracy: 0.6465 - val_loss: 1.0184
# Epoch 5/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 13s 8ms/step - accuracy: 0.6374 - loss: 1.0284 - val_accuracy: 0.6394 - val_loss: 1.0572
# Epoch 6/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 21s 9ms/step - accuracy: 0.6507 - loss: 0.9943 - val_accuracy: 0.6393 - val_loss: 1.0383
# Epoch 7/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 21s 9ms/step - accuracy: 0.6652 - loss: 0.9585 - val_accuracy: 0.6238 - val_loss: 1.1170
# Epoch 8/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 14s 9ms/step - accuracy: 0.6726 - loss: 0.9351 - val_accuracy: 0.6912 - val_loss: 0.8995
# Epoch 9/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 21s 9ms/step - accuracy: 0.6804 - loss: 0.9083 - val_accuracy: 0.6622 - val_loss: 1.0414
# Epoch 10/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 9ms/step - accuracy: 0.6853 - loss: 0.8937 - val_accuracy: 0.6670 - val_loss: 0.9730

# %% [markdown]
# # Evaluating the models and storing the results :

# %%
# Creating a list to store the results :
results = []

# Evaluating the models and storing the results :
for model, model_name in zip(models, model_names):
    _, accuracy = model.evaluate(x_test, y_test, verbose=0)
    results.append([model_name, accuracy])

# %% [markdown]
# # Displaying the comparison table as pandas dataframe :

# %%
# Creating a pandas DataFrame from the results :
df = pd.DataFrame(results, columns=['Model', 'Accuracy'])

# Displaying the comparison table :
display(df)
# Out:
#                         Model  Accuracy
# 0                  Simple CNN    0.7773
# 1     Deeper CNN with Dropout    0.7871
# 2  CNN with Data Augmentation    0.6670
